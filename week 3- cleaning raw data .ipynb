# %% [markdown]
# # BL-FLICKER IMAGES

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\DATA SCI\python project\BL-Flickr-Images-Book.csv")
df
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
df.isnull().sum()
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Identifier                  int64
# Edition Statement          object
# Place of Publication       object
# Date of Publication        object
# Publisher                  object
# Title                      object
# Author                     object
# Contributors               object
# Corporate Author          float64
# Corporate Contributors    float64
# Former owner               object
# Engraver                  float64
# Issuance type              object
# Flickr URL                 object
# Shelfmarks                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
 to_drop = ['Edition Statement',
            'Corporate Author',
            'Corporate Contributors',
            'Former owner',
            'Engraver',
            'Contributors',
            'Issuance type',
            'Shelfmarks']

# %%
df.drop(columns=to_drop, inplace=True)

# %%
df.isnull().sum()
# Out:
# Identifier                 0
# Place of Publication       0
# Date of Publication      181
# Publisher               4195
# Title                      0
# Author                  1778
# Flickr URL                 0
# dtype: int64

# %%
df['Publisher'].fillna(df['Publisher'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Identifier                 0
# Place of Publication       0
# Date of Publication      181
# Publisher                  0
# Title                      0
# Author                  1778
# Flickr URL                 0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Identifier                 0
# Place of Publication       0
# Date of Publication        0
# Publisher                  0
# Title                      0
# Author                  1778
# Flickr URL                 0
# dtype: int64

# %%
df['Author'].fillna(df['Author'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Identifier              0
# Place of Publication    0
# Date of Publication     0
# Publisher               0
# Title                   0
# Author                  0
# Flickr URL              0
# dtype: int64

# %%
regex = r'^(\d{4})'
df['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
# Out:
# 0       1879
# 1       1868
# 2       1869
# 3       1851
# 4       1857
#         ...
# 8282    1838
# 8283    1831
# 8284     NaN
# 8285    1834
# 8286    1834
# Name: Date of Publication, Length: 8287, dtype: object

# %%
np.where(df['Place of Publication'].str.contains('London'), 'London',
                                           df['Place of Publication'].str.replace('-', ' '))
# Out:
# array(['London', 'London', 'London', ..., 'London', 'Newcastle upon Tyne',
#        'London'], dtype=object)

# %% [markdown]
# # OLYMPICS

# %%
df_olympics = pd.read_csv(r"C:\Users\DELL\Desktop\DATA SCI\python project\olympics.csv", header=1)
df_olympics.head()
# Out:
#                 Unnamed: 0  ? Summer  01 !  02 !  03 !  Total  ? Winter  \
# 0        Afghanistan (AFG)        13     0     0     2      2         0
# 1            Algeria (ALG)        12     5     2     8     15         3
# 2          Argentina (ARG)        23    18    24    28     70        18
# 3            Armenia (ARM)         5     1     2     9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3     4     5     12         0
#
#    01 !.1  02 !.1  03 !.1  Total.1  ? Games  01 !.2  02 !.2  03 !.2  \
# 0       0       0       0        0       13       0       0       2
# 1       0       0       0        0       15       5       2       8
# 2       0       0       0        0       41      18      24      28
# 3       0       0       0        0       11       1       2       9
# 4       0       0       0        0        2       3       4       5
#
#    Combined total
# 0               2
# 1              15
# 2              70
# 3              12
# 4              12

# %%
df_olympics.rename(columns = {'Unnamed: 0': 'Country',
              '? Summer': 'Summer Olympics',
               '01 !': 'Gold',
               '02 !': 'Silver',
               '03 !': 'Bronze',
               '? Winter': 'Winter Olympics',
                '01 !.1': 'Gold.1',
              '02 !.1': 'Silver.1',
               '03 !.1': 'Bronze.1',
               '? Games': '# Games',
               '01 !.2': 'Gold.2',
               '02 !.2': 'Silver.2',
               '03 !.2': 'Bronze.2'}, inplace = True)

# %%
df_olympics.head()
# Out:
#                    Country  Summer Olympics  Gold  Silver  Bronze  Total  \
# 0        Afghanistan (AFG)               13     0       0       2      2
# 1            Algeria (ALG)               12     5       2       8     15
# 2          Argentina (ARG)               23    18      24      28     70
# 3            Armenia (ARM)                5     1       2       9     12
# 4  Australasia (ANZ) [ANZ]                2     3       4       5     12
#
#    Winter Olympics  Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# 0                0       0         0         0        0       13       0
# 1                3       0         0         0        0       15       5
# 2               18       0         0         0        0       41      18
# 3                6       0         0         0        0       11       1
# 4                0       0         0         0        0        2       3
#
#    Silver.2  Bronze.2  Combined total
# 0         0         2               2
# ...

# %%
df_olympics.isnull().sum()
# Out:
# Country            0
# Summer Olympics    0
# Gold               0
# Silver             0
# Bronze             0
# Total              0
# Winter Olympics    0
# Gold.1             0
# Silver.1           0
# Bronze.1           0
# Total.1            0
# # Games            0
# Gold.2             0
# Silver.2           0
# Bronze.2           0
# Combined total     0
# dtype: int64

# %%
df_olympics.dtypes
# Out:
# Country            object
# Summer Olympics     int64
# Gold                int64
# Silver              int64
# Bronze              int64
# Total               int64
# Winter Olympics     int64
# Gold.1              int64
# Silver.1            int64
# Bronze.1            int64
# Total.1             int64
# # Games             int64
# Gold.2              int64
# Silver.2            int64
# Bronze.2            int64
# Combined total      int64
# dtype: object

# %% [markdown]
# # university towns

# %%
df_uni = pd.read_csv(r"C:\Users\DELL\Desktop\DATA SCI\python project\university_towns.txt", sep="\t", header=None)
df_uni
# Out:
#                                                      0
# 0                                        Alabama[edit]
# 1                        Auburn (Auburn University)[1]
# 2               Florence (University of North Alabama)
# 3      Jacksonville (Jacksonville State University)[2]
# 4           Livingston (University of West Alabama)[2]
# ..                                                 ...
# 562  Stevens Point (University of Wisconsin–Stevens...
# 563                      Waukesha (Carroll University)
# 564  Whitewater (University of Wisconsin–Whitewater...
# 565                                      Wyoming[edit]
# 566                 Laramie (University of Wyoming)[5]
#
# [567 rows x 1 columns]

# %%
uni_towns = pd.DataFrame(df_uni, columns=['State', 'RegionName'])
uni_towns
# Out:
#      State  RegionName
# 0      NaN         NaN
# 1      NaN         NaN
# 2      NaN         NaN
# 3      NaN         NaN
# 4      NaN         NaN
# ..     ...         ...
# 561    NaN         NaN
# 562    NaN         NaN
# 563    NaN         NaN
# 564    NaN         NaN
# 565    NaN         NaN
#
# [566 rows x 2 columns]

# %% [markdown]
# # TMDB-movies

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\DATA SCI\python project\tmdb-movies.csv")
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
df['imdb_id'].fillna(df['imdb_id'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                    0
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df['homepage']=df['homepage'].fillna('missing')

# %%
df.apply(lambda x:sum(x.isnull()))
# Out:
# id                         0
# imdb_id                    0
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                   0
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df['tagline']=df['tagline'].fillna('missing')

# %%
df.apply(lambda x:sum(x.isnull()))
# Out:
# id                         0
# imdb_id                    0
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                   0
# director                  44
# tagline                    0
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df['keywords']=df['keywords'].fillna('missing')

# %%
df.apply(lambda x:sum(x.isnull()))
# Out:
# id                         0
# imdb_id                    0
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                   0
# director                  44
# tagline                    0
# keywords                   0
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df['production_companies'].fillna(df['production_companies'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                       0
# imdb_id                  0
# popularity               0
# budget                   0
# revenue                  0
# original_title           0
# cast                    76
# homepage                 0
# director                44
# tagline                  0
# keywords                 0
# overview                 4
# runtime                  0
# genres                  23
# production_companies     0
# release_date             0
# vote_count               0
# vote_average             0
# release_year             0
# budget_adj               0
# revenue_adj              0
# dtype: int64

# %%
df['genres'].fillna(df['genres'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                       0
# imdb_id                  0
# popularity               0
# budget                   0
# revenue                  0
# original_title           0
# cast                    76
# homepage                 0
# director                44
# tagline                  0
# keywords                 0
# overview                 4
# runtime                  0
# genres                   0
# production_companies     0
# release_date             0
# vote_count               0
# vote_average             0
# release_year             0
# budget_adj               0
# revenue_adj              0
# dtype: int64

# %%
df['cast'].fillna(df['cast'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                       0
# imdb_id                  0
# popularity               0
# budget                   0
# revenue                  0
# original_title           0
# cast                     0
# homepage                 0
# director                44
# tagline                  0
# keywords                 0
# overview                 4
# runtime                  0
# genres                   0
# production_companies     0
# release_date             0
# vote_count               0
# vote_average             0
# release_year             0
# budget_adj               0
# revenue_adj              0
# dtype: int64

# %%
df['director'].fillna(df['director'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                4
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %%
df['overview'].fillna(df['overview'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %% [markdown]
# # restaurant tips missing

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\DATA SCI\python project\Restaurant_tips_Missing1.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 239         NaN  5.92    Male     No   Sat  Dinner   3.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [244 rows x 7 columns]

# %%
df['time'].fillna(df['time'].mode()[0], inplace=True)

# %%
df.apply(lambda x:sum(x.isnull()))

# %%
df['smoker'].fillna(df['smoker'].mode()[0], inplace=True)

# %%
df.apply(lambda x:sum(x.isnull()))

# %%
df[['time', 'smoker']].fillna(df[['time', 'smoker']].mean())

# %%
df['sex'].mode()

# %%
df['day'].mode()

# %%
df['time'].mode()

# %%
df['sex'].mode()
